# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
os.chdir("/home/luca/Scrivania/wraplot")

# %%
import numpy as np
import matplotlib
matplotlib.use("Agg")

from wraplot.plotter import *

# %%
sparse_matrix = (np.random.rand(100, 100) > .5).astype(np.float)
dense_matrix = np.random.rand(100, 100).astype(np.float)
points = np.random.rand(100, 3)

# %% [markdown]
# # Spy

# %%
spyplot = Spy(figsize=(5, 5))
spyplot(Spy.Object(matrix=sparse_matrix, markersize=4))

# %% [markdown]
# # Imagesc

# %%
imagescplot = Imagesc(figsize=(5, 5))
imagescplot(Imagesc.Object(matrix=dense_matrix))

# %% [markdown]
# # Plotcloud2D

# %%
cloudplotter = PlotCloud2D(figsize=(5, 5))
cloudplotter(PlotCloud2D.Object(points=points))

# %% [markdown]
# # Plot bar comparison

# %%
barplotter = PlotCoupledBarsComparison()
o = barplotter.Object(
    bar1_values=['adf', 'sf'],
    bar2_values=[1, 3],
    label1 = 'a',
    label2 = 'b',
    xticklabels=['1a', '1b'],
    
    title='ciao',
    titlesize=50,
    
    subtitle='ooo'
)

# %%
sub = Subplotter()

sub([o, o], plot_functions=barplotter, subplotadjust=0.5)

# %%
# Imagesc = wraplot.plotter.Imagesc
# Animator = wraplot.plotter.Animator

m = np.random.rand(100, 100).astype(np.float)

imagescplot = Imagesc(figsize=(5, 5))

animator = Animator()
for i in range(10):
    animator.add(Imagesc.Object(matrix=np.random.rand(100, 100).astype(np.float)),
                 imagescplot)
    m = m * 0.01

animator.save("test.gif")
print('ok')
# Out:
# ok
